# %%
import cv2

# %%
image = cv2.imread("segf/dataset1/images_prepped_train/0006R0_f02130.png")

# %%
mask = cv2.imread("segf/dataset1/annotations_prepped_train/0006R0_f02130.png", -1)

# %%
mask.shape
# Out:
# (360, 480)

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
from skimage.color import label2rgb

# %%
resp = label2rgb(mask, image)
# Out:
# c:\users\faizan\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The new recommended value for bg_label is 0. Until version 0.19, the default bg_label value is -1. From version 0.19, the bg_label default value will be 0. To avoid this warning, please explicitly set bg_label value.
#   """Entry point for launching an IPython kernel.

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(resp)
